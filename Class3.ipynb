# %%
import sys
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab import drive
drive.mount('/content/drive')

#主函數
if __name__ =="__main__":
  if len(sys.argv)>1:
    image = cv2.imread('/content/drive/My Drive/107-2Multimedia/pic.jpg', cv2.IMREAD_GRAYSCALE)
  else:
    print("Usge:python imToArray.py imageFile")#https://blog.csdn.net/lanchunhui/article/details/66972783
  plt.imshow(image,cmap='gray')
  plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
image2 = cv2.imread('/content/drive/My Drive/107-2Multimedia/pic.jpg', cv2.IMREAD_COLOR)#default
# plt.imshow(image2)
plt.imshow(cv2.cvtColor(image2,cv2.COLOR_BGR2RGB))
plt.show()

# %%
image3 = cv2.imread('/content/drive/My Drive/107-2Multimedia/pic.jpg', cv2.IMREAD_UNCHANGED)#including alpha channel
plt.imshow(cv2.cvtColor(image3,cv2.COLOR_BGR2RGB))
plt.show()

# %%
image4 = cv2.imread('/content/drive/My Drive/107-2Multimedia/pic.jpg', 0)# -1 0 1 2 3 4....................
plt.imshow(image4)
plt.title('invert')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image5 = cv2.imread('/content/drive/My Drive/107-2Multimedia/pic.jpg')
gray = cv2.cvtColor(image5, cv2.COLOR_BGR2GRAY)
gray
# Out:
# array([[ 99,  99,  99, ..., 107, 107, 107],
#        [ 99,  99,  99, ..., 107, 107, 107],
#        [ 99,  99,  99, ..., 107, 107, 107],
#        ...,
#        [199, 199, 198, ..., 181, 179, 178],
#        [198, 198, 198, ..., 180, 178, 176],
#        [198, 197, 196, ..., 173, 171, 169]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')
plt.title('gray')
plt.xticks([])
plt.yticks([])
plt.show()

# %%
image6 = cv2.imread('/content/drive/My Drive/107-2Multimedia/pic.jpg')
b,g,r = cv2.split(image6)#slow
img = cv2.merge((r,g,b))#slow
plt.imshow(img)
plt.title('color')
plt.xticks([])
plt.yticks([])
plt.show()
